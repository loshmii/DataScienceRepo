# %%
print("My Python3 Notebook")
# Out:
# My Python3 Notebook

# %%
#THIS IS A HEADER

# %%
import numpy as np
import matplotlib.pyplot as plt

def main() :
    x = np.arange(0,2*np.pi,0.01)
    y = np.cos(x)
    plt.plot(x,y)
    plt.show

# %%
main()
